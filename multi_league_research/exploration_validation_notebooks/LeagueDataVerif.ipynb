# %% [markdown]
# # TheStatsAPI league coverage audit
#
# This notebook screens Greece, the Netherlands, Turkey, Belgium, Portugal, and Scotland for seasons **2020-21 through 2025-26**.
#
# The audit uses every fixture for fixture coverage and Football-Data joining, but only five deterministic matches per league-season for expensive lineup and player-stat checks. Successful API responses are cached locally, so rerunning the notebook does not spend requests twice.
#
# Set `RUN_AUDIT = True` only when ready. The notebook has a hard 750-request ceiling for this run, preserving most of the 10,000-request trial. Sample-based checks are provisional; a passing league is a candidate for full collection, not a final guarantee.

# %%
import hashlib
import json
import os
import re
import sqlite3
import time
from pathlib import Path
from typing import Any

import pandas as pd
import requests
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.environ["THESTATSAPI_KEY"]
BASE_URL = "https://api.thestatsapi.com/api"
ODDS_DB = Path("odds.db")
CACHE_DIR = Path("data/statsapi_audit_cache")
CACHE_DIR.mkdir(parents=True, exist_ok=True)

# Safety switch: inspect the estimated request count before changing this.
RUN_AUDIT = True
REQUEST_BUDGET = 750
REQUEST_SLEEP_SEC = 2.5
MAX_429_RETRIES = 5
SAMPLE_MATCHES_PER_SEASON = 5
SEASON_START_YEARS = list(range(2020, 2026))

LEAGUES = {
    "greece": {"competition_id": "comp_4008", "division": "G1"},
    "netherlands": {"competition_id": "comp_3809", "division": "N1"},
    "turkey": {"competition_id": "comp_9235", "division": "T1"},
    "belgium": {"competition_id": "comp_8531", "division": "B1"},
    "portugal": {"competition_id": "comp_8385", "division": "P1"},
    "scotland": {"competition_id": "comp_6387", "division": "SC0"},
}

THRESHOLDS = {
    "fixture_coverage": 0.95,
    "both_lineups": 0.90,
    "twenty_two_starters": 0.90,
    "player_stats_matches": 0.90,
    "starter_minutes": 0.90,
    "player_identity": 0.99,
    "football_data_join": 0.95,
}

estimated_detail_requests = (
    len(LEAGUES) * len(SEASON_START_YEARS) * SAMPLE_MATCHES_PER_SEASON * 2
)
estimated_list_requests = len(LEAGUES) + len(LEAGUES) * len(SEASON_START_YEARS) * 4
print("Conservative first-run estimate:", estimated_detail_requests + estimated_list_requests)
print("Hard request budget:", REQUEST_BUDGET)
print("Cached responses make later reruns cheaper.")
# Out:
# Conservative first-run estimate: 510
# Hard request budget: 750
# Cached responses make later reruns cheaper.

# %%
SESSION = requests.Session()
SESSION.headers.update({"Authorization": f"Bearer {API_KEY}"})
REQUESTS_USED_THIS_RUN = 0
CACHE_HITS_THIS_RUN = 0


class ApiError(RuntimeError):
    pass


def _cache_path(path: str, params: dict | None) -> Path:
    raw = json.dumps([path, params or {}], sort_keys=True, default=str).encode()
    return CACHE_DIR / f"{hashlib.sha256(raw).hexdigest()}.json"


def api_get(path: str, params: dict | None = None, *, use_cache: bool = True) -> dict:
    global REQUESTS_USED_THIS_RUN, CACHE_HITS_THIS_RUN
    cache_path = _cache_path(path, params)
    if use_cache and cache_path.exists():
        CACHE_HITS_THIS_RUN += 1
        return json.loads(cache_path.read_text(encoding="utf-8"))

    url = f"{BASE_URL}{path}"
    for attempt in range(MAX_429_RETRIES + 1):
        if REQUESTS_USED_THIS_RUN >= REQUEST_BUDGET:
            raise ApiError(f"Stopped at the {REQUEST_BUDGET}-request notebook budget")
        if REQUESTS_USED_THIS_RUN:
            time.sleep(REQUEST_SLEEP_SEC)
        response = SESSION.get(url, params=params or {}, timeout=30)
        REQUESTS_USED_THIS_RUN += 1

        if response.status_code == 429 and attempt < MAX_429_RETRIES:
            retry_after = response.headers.get("Retry-After")
            wait = float(retry_after) if retry_after else min(60, 5 * (2**attempt))
            print(f"Rate limited; waiting {wait:.0f}s before retrying")
            time.sleep(wait)
            continue

        if not response.ok:
            try:
                error = response.json().get("error", {})
                message = error.get("message", response.text)
            except Exception:
                message = response.text
            raise ApiError(f"{response.status_code} {path}: {message}")

        payload = response.json()
        if use_cache:
            cache_path.write_text(json.dumps(payload), encoding="utf-8")
        return payload

    raise ApiError(f"Repeated rate limits for {path}")


def api_paginate(path: str, params: dict | None = None) -> list[dict]:
    params = dict(params or {})
    params.setdefault("per_page", 100)
    rows = []
    page = 1
    while True:
        payload = api_get(path, {**params, "page": page})
        rows.extend(payload.get("data", []))
        total_pages = payload.get("meta", {}).get("total_pages", page)
        if page >= total_pages:
            return rows
        page += 1

# %%
# Known provider-name differences. Add aliases only when the unmatched-team table shows a real mismatch.
TEAM_ALIASES = {
    "aekathens": "aek",
    "asterasaktor": "asterastripolis",
    "atromitosathens": "atromitos",
    "aristhessaloniki": "aris",
    "athenskallitheafc": "athenskallithea",
    "mgspanserraikos": "panserraikos",
}


def normalize_team_name(name: str) -> str:
    value = (name or "").lower().strip()
    value = re.sub(r"\b(fc|cf|sc|afc|fk|sk)\b", "", value)
    value = re.sub(r"[^a-z0-9]", "", value)
    return TEAM_ALIASES.get(value, value)


def season_label(start_year: int) -> str:
    return f"{start_year}-{(start_year + 1) % 100:02d}"


def load_football_data(division: str, start_year: int) -> pd.DataFrame:
    query = """
        SELECT match_date, home_team, away_team, result_3way, odds_is_closing
        FROM historical_results_odds
        WHERE division = ? AND season = ?
    """
    with sqlite3.connect(ODDS_DB) as connection:
        frame = pd.read_sql_query(query, connection, params=[division, season_label(start_year)])
    frame["fd_key"] = (
        frame["match_date"].astype(str)
        + "|" + frame["home_team"].map(normalize_team_name)
        + "|" + frame["away_team"].map(normalize_team_name)
    )
    return frame

# %%
def find_season_id(competition_id: str, start_year: int) -> str | None:
    seasons = api_paginate(f"/football/competitions/{competition_id}/seasons")
    match = next(
        (season for season in seasons
         if season.get("start_year") == start_year
         and season.get("end_year") == start_year + 1),
        None,
    )
    return None if match is None else match["id"]


def load_statsapi_matches(competition_id: str, season_id: str) -> pd.DataFrame:
    matches = api_paginate(
        "/football/matches",
        {"competition_id": competition_id, "season_id": season_id, "status": "finished"},
    )
    if not matches:
        return pd.DataFrame()
    frame = pd.DataFrame(matches)
    frame["utc_date"] = pd.to_datetime(frame["utc_date"], utc=True)
    frame["match_date"] = frame["utc_date"].dt.strftime("%Y-%m-%d")
    frame["home_name"] = frame["home_team"].map(lambda value: value.get("name"))
    frame["away_name"] = frame["away_team"].map(lambda value: value.get("name"))
    frame["stats_key"] = (
        frame["match_date"]
        + "|" + frame["home_name"].map(normalize_team_name)
        + "|" + frame["away_name"].map(normalize_team_name)
    )
    return frame.sort_values(["utc_date", "id"]).reset_index(drop=True)


def deterministic_sample(frame: pd.DataFrame, size: int) -> pd.DataFrame:
    if len(frame) <= size:
        return frame.copy()
    indexes = [round(i * (len(frame) - 1) / (size - 1)) for i in range(size)]
    return frame.iloc[indexes].copy()

# %%
def _player_id(record: dict) -> Any:
    nested = record.get("player") or {}
    return record.get("player_id") or record.get("id") or nested.get("id")


def _player_name(record: dict) -> str | None:
    nested = record.get("player") or {}
    return record.get("player_name") or record.get("name") or nested.get("name")


def _minutes(record: dict) -> Any:
    return record.get("minutes", record.get("minutes_played"))


def fetch_optional(path: str, params: dict | None = None) -> tuple[Any, str | None]:
    try:
        return api_get(path, params).get("data"), None
    except ApiError as error:
        return None, str(error)


def audit_match(row: pd.Series) -> dict:
    match_id = row["id"]
    lineups, lineup_error = fetch_optional(f"/football/matches/{match_id}/lineups")
    # The public API documentation exposes per-match player rows through this endpoint/filter.
    stats, stats_error = fetch_optional("/football/players/stats", {"match_id": match_id, "per_page": 100})
    lineups = lineups or {}
    stats = stats or []

    home_xi = (lineups.get("home") or {}).get("starting_xi") or []
    away_xi = (lineups.get("away") or {}).get("starting_xi") or []
    starters = home_xi + away_xi
    starter_ids = [_player_id(player) for player in starters if _player_id(player)]
    stats_by_player = {_player_id(player): player for player in stats if _player_id(player)}
    starters_with_minutes = sum(
        1 for player_id in starter_ids
        if player_id in stats_by_player and _minutes(stats_by_player[player_id]) is not None
    )

    identity_records = list(starters) + list(stats)
    identity_with_id = sum(bool(_player_id(player)) for player in identity_records)
    stat_fields = sorted({key for player in stats for key in player.keys()})

    return {
        "match_id": match_id,
        "match_date": row["match_date"],
        "home_team": row["home_name"],
        "away_team": row["away_name"],
        "both_lineups": bool(home_xi) and bool(away_xi),
        "starter_count": len(starters),
        "twenty_two_starters": len(starters) == 22,
        "player_stats_available": bool(stats),
        "starters_with_minutes": starters_with_minutes,
        "starters_with_id": len(starter_ids),
        "identity_rows": len(identity_records),
        "identity_rows_with_id": identity_with_id,
        "player_stat_fields": stat_fields,
        "lineup_error": lineup_error,
        "stats_error": stats_error,
    }

# %%
audit_rows = []
detail_rows = []
unmatched_rows = []

if not RUN_AUDIT:
    print("Dry run only. Review the configuration, then set RUN_AUDIT = True and rerun from the top.")
else:
    for league, config in LEAGUES.items():
        print(f"\n--- {league.upper()} ---")
        for start_year in SEASON_START_YEARS:
            label = season_label(start_year)
            season_id = find_season_id(config["competition_id"], start_year)
            fd = load_football_data(config["division"], start_year)

            if season_id is None:
                audit_rows.append({
                    "league": league, "season": label, "season_found": False,
                    "fd_fixtures": len(fd), "api_fixtures": 0,
                })
                print(label, "season unavailable")
                continue

            matches = load_statsapi_matches(config["competition_id"], season_id)
            if matches.empty:
                audit_rows.append({
                    "league": league, "season": label, "season_found": True,
                    "fd_fixtures": len(fd), "api_fixtures": 0,
                })
                print(label, "no finished matches")
                continue

            joined = matches.merge(fd[["fd_key"]], left_on="stats_key", right_on="fd_key", how="left")
            unmatched = joined[joined["fd_key"].isna()][["match_date", "home_name", "away_name"]].copy()
            if not unmatched.empty:
                unmatched.insert(0, "season", label)
                unmatched.insert(0, "league", league)
                unmatched_rows.extend(unmatched.to_dict("records"))

            sample = deterministic_sample(matches, SAMPLE_MATCHES_PER_SEASON)
            season_details = []
            for _, match in sample.iterrows():
                detail = audit_match(match)
                detail.update({"league": league, "season": label})
                season_details.append(detail)
                detail_rows.append(detail)

            details = pd.DataFrame(season_details)
            total_starters = int(details["starters_with_id"].sum())
            total_identity_rows = int(details["identity_rows"].sum())
            xg_rate = float(matches.get("xg_available", pd.Series(False, index=matches.index)).fillna(False).mean())
            audit_rows.append({
                "league": league,
                "season": label,
                "season_found": True,
                "fd_fixtures": len(fd),
                "api_fixtures": len(matches),
                "fixture_coverage": len(matches) / len(fd) if len(fd) else None,
                "football_data_join": joined["fd_key"].notna().mean(),
                "sample_matches": len(details),
                "both_lineups": details["both_lineups"].mean(),
                "twenty_two_starters": details["twenty_two_starters"].mean(),
                "player_stats_matches": details["player_stats_available"].mean(),
                "starter_minutes": details["starters_with_minutes"].sum() / total_starters if total_starters else 0.0,
                "player_identity": details["identity_rows_with_id"].sum() / total_identity_rows if total_identity_rows else 0.0,
                "xg_flag_rate": xg_rate,
            })
            print(label, f"fixtures={len(matches)}, detailed_sample={len(details)}")

    print(f"\nRequests used this run: {REQUESTS_USED_THIS_RUN}")
    print(f"Cache hits this run: {CACHE_HITS_THIS_RUN}")
# Out:
# --- GREECE ---
# 2020-21 fixtures=239, detailed_sample=5
# 2021-22 fixtures=242, detailed_sample=5
# 2022-23 fixtures=240, detailed_sample=5
# 2023-24 fixtures=240, detailed_sample=5
# Rate limited; waiting 25s before retrying
# 2024-25 fixtures=236, detailed_sample=5
# 2025-26 fixtures=236, detailed_sample=5
#
# --- NETHERLANDS ---
# Rate limited; waiting 24s before retrying
# 2020-21 fixtures=286, detailed_sample=5
# 2021-22 fixtures=302, detailed_sample=5
# Rate limited; waiting 25s before retrying
# 2022-23 fixtures=306, detailed_sample=5
# 2023-24 fixtures=321, detailed_sample=5
# 2024-25 fixtures=321, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2025-26 fixtures=321, detailed_sample=5
#
# --- TURKEY ---
# 2020-21 fixtures=420, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2021-22 fixtures=380, detailed_sample=5
# 2022-23 fixtures=313, detailed_sample=5
# 2023-24 fixtures=379, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2024-25 fixtures=342, detailed_sample=5
# 2025-26 fixtures=306, detailed_sample=5
#
# --- BELGIUM ---
# Rate limited; waiting 25s before retrying
# 2020-21 fixtures=332, detailed_sample=5
# 2021-22 fixtures=330, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2022-23 fixtures=330, detailed_sample=5
# 2023-24 fixtures=320, detailed_sample=5
# 2024-25 fixtures=320, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2025-26 fixtures=321, detailed_sample=5
#
# --- PORTUGAL ---
# Rate limited; waiting 24s before retrying
# 2020-21 fixtures=308, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2021-22 fixtures=308, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2022-23 fixtures=308, detailed_sample=5
# Rate limited; waiting 24s before retrying
# Rate limited; waiting 23s before retrying
# 2023-24 fixtures=308, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2024-25 fixtures=308, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2025-26 fixtures=308, detailed_sample=5
#
# --- SCOTLAND ---
# Rate limited; waiting 24s before retrying
# 2020-21 fixtures=233, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2021-22 fixtures=234, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2022-23 fixtures=234, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2023-24 fixtures=234, detailed_sample=5
# Rate limited; waiting 23s before retrying
# 2024-25 fixtures=234, detailed_sample=5
# Rate limited; waiting 24s before retrying
# 2025-26 fixtures=234, detailed_sample=5
#
# Requests used this run: 306
# Cache hits this run: 244

# %%
if not audit_rows:
    print("No results yet. Run the previous cell with RUN_AUDIT = True.")
else:
    audit_summary = pd.DataFrame(audit_rows)
    metric_columns = list(THRESHOLDS)
    for metric in metric_columns:
        audit_summary[f"{metric}_pass"] = audit_summary.get(metric, pd.Series(index=audit_summary.index)).ge(THRESHOLDS[metric])

    pass_columns = [f"{metric}_pass" for metric in metric_columns]
    audit_summary["provisional_pass"] = (
        audit_summary["season_found"].fillna(False)
        & audit_summary[pass_columns].fillna(False).all(axis=1)
    )

    display_columns = [
        "league", "season", "fd_fixtures", "api_fixtures",
        "fixture_coverage", "football_data_join", "both_lineups",
        "twenty_two_starters", "player_stats_matches",
        "starter_minutes", "player_identity", "xg_flag_rate",
        "provisional_pass",
    ]
    display(audit_summary[[column for column in display_columns if column in audit_summary]].style.format({
        column: "{:.1%}" for column in display_columns if column in THRESHOLDS or column == "xg_flag_rate"
    }))
# Out:
# <style type="text/css">
# </style>
# <table id="T_f5796">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5796_level0_col0" class="col_heading level0 col0" >league</th>
#       <th id="T_f5796_level0_col1" class="col_heading level0 col1" >season</th>
#       <th id="T_f5796_level0_col2" class="col_heading level0 col2" >fd_fixtures</th>
#       <th id="T_f5796_level0_col3" class="col_heading level0 col3" >api_fixtures</th>
#       <th id="T_f5796_level0_col4" class="col_heading level0 col4" >fixture_coverage</th>
#       <th id="T_f5796_level0_col5" class="col_heading level0 col5" >football_data_join</th>
#       <th id="T_f5796_level0_col6" class="col_heading level0 col6" >both_lineups</th>
#       <th id="T_f5796_level0_col7" class="col_heading level0 col7" >twenty_two_starters</th>
#       <th id="T_f5796_level0_col8" class="col_heading level0 col8" >player_stats_matches</th>
#       <th id="T_f5796_level0_col9" class="col_heading level0 col9" >starter_minutes</th>
#       <th id="T_f5796_level0_col10" class="col_heading level0 col10" >player_identity</th>
#       <th id="T_f5796_level0_col11" class="col_heading level0 col11" >xg_flag_rate</th>
#       <th id="T_f5796_level0_col12" class="col_heading level0 col12" >provisional_pass</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5796_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5796_row0_col0" class="data row0 col0" >greece</td>
#       <td id="T_f5796_row0_col1" class="data row0 col1" >2020-21</td>
#       <td id="T_f5796_row0_col2" class="data row0 col2" >240</td>
#       <td id="T_f5796_row0_col3" class="data row0 col3" >239</td>
#       <td id="T_f5796_row0_col4" class="data row0 col4" >99.6%</td>
#       <td id="T_f5796_row0_col5" class="data row0 col5" >32.2%</td>
#       <td id="T_f5796_row0_col6" class="data row0 col6" >0.0%</td>
#       <td id="T_f5796_row0_col7" class="data row0 col7" >0.0%</td>
#       <td id="T_f5796_row0_col8" class="data row0 col8" >0.0%</td>
#       <td id="T_f5796_row0_col9" class="data row0 col9" >0.0%</td>
#       <td id="T_f5796_row0_col10" class="data row0 col10" >0.0%</td>
#       <td id="T_f5796_row0_col11" class="data row0 col11" >0.0%</td>
#       <td id="T_f5796_row0_col12" class="data row0 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5796_row1_col0" class="data row1 col0" >greece</td>
#       <td id="T_f5796_row1_col1" class="data row1 col1" >2021-22</td>
#       <td id="T_f5796_row1_col2" class="data row1 col2" >240</td>
#       <td id="T_f5796_row1_col3" class="data row1 col3" >242</td>
#       <td id="T_f5796_row1_col4" class="data row1 col4" >100.8%</td>
#       <td id="T_f5796_row1_col5" class="data row1 col5" >38.8%</td>
#       <td id="T_f5796_row1_col6" class="data row1 col6" >0.0%</td>
#       <td id="T_f5796_row1_col7" class="data row1 col7" >0.0%</td>
#       <td id="T_f5796_row1_col8" class="data row1 col8" >0.0%</td>
#       <td id="T_f5796_row1_col9" class="data row1 col9" >0.0%</td>
#       <td id="T_f5796_row1_col10" class="data row1 col10" >0.0%</td>
#       <td id="T_f5796_row1_col11" class="data row1 col11" >0.0%</td>
#       <td id="T_f5796_row1_col12" class="data row1 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5796_row2_col0" class="data row2 col0" >greece</td>
#       <td id="T_f5796_row2_col1" class="data row2 col1" >2022-23</td>
#       <td id="T_f5796_row2_col2" class="data row2 col2" >240</td>
#       <td id="T_f5796_row2_col3" class="data row2 col3" >240</td>
#       <td id="T_f5796_row2_col4" class="data row2 col4" >100.0%</td>
#       <td id="T_f5796_row2_col5" class="data row2 col5" >39.2%</td>
#       <td id="T_f5796_row2_col6" class="data row2 col6" >100.0%</td>
#       <td id="T_f5796_row2_col7" class="data row2 col7" >100.0%</td>
#       <td id="T_f5796_row2_col8" class="data row2 col8" >0.0%</td>
#       <td id="T_f5796_row2_col9" class="data row2 col9" >0.0%</td>
#       <td id="T_f5796_row2_col10" class="data row2 col10" >100.0%</td>
#       <td id="T_f5796_row2_col11" class="data row2 col11" >79.2%</td>
#       <td id="T_f5796_row2_col12" class="data row2 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f5796_row3_col0" class="data row3 col0" >greece</td>
#       <td id="T_f5796_row3_col1" class="data row3 col1" >2023-24</td>
#       <td id="T_f5796_row3_col2" class="data row3 col2" >240</td>
#       <td id="T_f5796_row3_col3" class="data row3 col3" >240</td>
#       <td id="T_f5796_row3_col4" class="data row3 col4" >100.0%</td>
#       <td id="T_f5796_row3_col5" class="data row3 col5" >39.2%</td>
#       <td id="T_f5796_row3_col6" class="data row3 col6" >100.0%</td>
#       <td id="T_f5796_row3_col7" class="data row3 col7" >100.0%</td>
#       <td id="T_f5796_row3_col8" class="data row3 col8" >0.0%</td>
#       <td id="T_f5796_row3_col9" class="data row3 col9" >0.0%</td>
#       <td id="T_f5796_row3_col10" class="data row3 col10" >100.0%</td>
#       <td id="T_f5796_row3_col11" class="data row3 col11" >86.7%</td>
#       <td id="T_f5796_row3_col12" class="data row3 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f5796_row4_col0" class="data row4 col0" >greece</td>
#       <td id="T_f5796_row4_col1" class="data row4 col1" >2024-25</td>
#       <td id="T_f5796_row4_col2" class="data row4 col2" >233</td>
#       <td id="T_f5796_row4_col3" class="data row4 col3" >236</td>
#       <td id="T_f5796_row4_col4" class="data row4 col4" >101.3%</td>
#       <td id="T_f5796_row4_col5" class="data row4 col5" >47.9%</td>
#       <td id="T_f5796_row4_col6" class="data row4 col6" >100.0%</td>
#       <td id="T_f5796_row4_col7" class="data row4 col7" >100.0%</td>
#       <td id="T_f5796_row4_col8" class="data row4 col8" >0.0%</td>
#       <td id="T_f5796_row4_col9" class="data row4 col9" >0.0%</td>
#       <td id="T_f5796_row4_col10" class="data row4 col10" >100.0%</td>
#       <td id="T_f5796_row4_col11" class="data row4 col11" >5.1%</td>
#       <td id="T_f5796_row4_col12" class="data row4 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f5796_row5_col0" class="data row5 col0" >greece</td>
#       <td id="T_f5796_row5_col1" class="data row5 col1" >2025-26</td>
#       <td id="T_f5796_row5_col2" class="data row5 col2" >236</td>
#       <td id="T_f5796_row5_col3" class="data row5 col3" >236</td>
#       <td id="T_f5796_row5_col4" class="data row5 col4" >100.0%</td>
#       <td id="T_f5796_row5_col5" class="data row5 col5" >39.0%</td>
#       <td id="T_f5796_row5_col6" class="data row5 col6" >100.0%</td>
#       <td id="T_f5796_row5_col7" class="data row5 col7" >100.0%</td>
#       <td id="T_f5796_row5_col8" class="data row5 col8" >0.0%</td>
#       <td id="T_f5796_row5_col9" class="data row5 col9" >0.0%</td>
#       <td id="T_f5796_row5_col10" class="data row5 col10" >100.0%</td>
#       <td id="T_f5796_row5_col11" class="data row5 col11" >100.0%</td>
#       <td id="T_f5796_row5_col12" class="data row5 col12" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f5796_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f5796_row6_col0" class="data row6 col0" >netherlands</td>
#       <td id="T_f5796_row6_col1" class="data row6 col1" >2020-21</td>
#       <td id="T_f5796_row6_col2" class="data row6 col2" >306</td>
#       <td id="T_f5796_row6_col3" class="data row6 col3" >286</td>
#       <td id="T_f5796_row6_col4" class="data row6 col4" >93.5%</td>
#       <td id="T_f5796_row6_col5" class="data row6 col5" >40.6%</td>
#       <td id="T_f5796_row6_col6" class="data row6 col6" >100.0%</td>
#       <td id="T_f5796_row6_col7" class="data row6 col7" >100.0%</td>
#       <td id="T_f5796_row6_col8" class="data row6 col8" >0.0%</td>
#       <td id="T_f5796_row6_col9" class="data row6 col9" >0.0%</td>
#       <td id="T_f5796_row6_col10" class="da

# %%
if detail_rows:
    detail_df = pd.DataFrame(detail_rows)

    field_rows = []
    for (league, season), group in detail_df.groupby(["league", "season"]):
        field_sets = [set(fields) for fields in group["player_stat_fields"] if fields]
        fields = sorted(set().union(*field_sets)) if field_sets else []
        field_rows.append({"league": league, "season": season, "player_stat_fields": ", ".join(fields)})
    field_summary = pd.DataFrame(field_rows)
    display(field_summary)

    errors = detail_df[detail_df["lineup_error"].notna() | detail_df["stats_error"].notna()][
        ["league", "season", "match_id", "lineup_error", "stats_error"]
    ]
    if not errors.empty:
        print("Endpoint errors to inspect:")
        display(errors)

if unmatched_rows:
    print("Unmatched provider names. Add only confirmed differences to TEAM_ALIASES, then rerun; cached API calls will be reused.")
    display(pd.DataFrame(unmatched_rows).drop_duplicates().head(100))
# Out:
#          league   season player_stat_fields
# 0       belgium  2020-21
# 1       belgium  2021-22
# 2       belgium  2022-23
# 3       belgium  2023-24
# 4       belgium  2024-25
# 5       belgium  2025-26
# 6        greece  2020-21
# 7        greece  2021-22
# 8        greece  2022-23
# 9        greece  2023-24
# 10       greece  2024-25
# 11       greece  2025-26
# 12  netherlands  2020-21
# 13  netherlands  2021-22
# 14  netherlands  2022-23
# 15  netherlands  2023-24
# 16  netherlands  2024-25
# 17  netherlands  2025-26
# 18     portugal  2020-21
# 19     portugal  2021-22
# 20     portugal  2022-23
# 21     portugal  2023-24
# 22     portugal  2024-25
# 23     portugal  2025-26
# 24     scotland  2020-21
# 25     scotland  2021-22
# 26     scotland  2022-23
# 27     scotland  2023-24
# 28     scotland  2024-25
# 29     scotland  2025-26
# 30       turkey  2020-21
# 31       turkey  2021-22
# 32       turkey  2022-23
# 33       turkey  2023-24
# 34       turkey  2024-25
# 35       turkey  2025-26
# Endpoint errors to inspect:
#        league   season      match_id lineup_error  \
# 0      greece  2020-21  mt_304352111          NaN
# 1      greece  2020-21  mt_727240705          NaN
# 2      greece  2020-21  mt_303785312          NaN
# 3      greece  2020-21  mt_969816089          NaN
# 4      greece  2020-21  mt_727799166          NaN
# ..        ...      ...           ...          ...
# 175  scotland  2025-26  mt_252089709          NaN
# 176  scotland  2025-26  mt_838964064          NaN
# 177  scotland  2025-26  mt_252089875          NaN
# 178  scotland  2025-26  mt_626451024          NaN
# 179  scotland  2025-26  mt_733925402          NaN
#
#                                         stats_error
# 0    400 /football/players/stats: Invalid player_id
# 1    400 /football/players/stats: Invalid player_id
# 2    400 /football/players/stats: Invalid player_id
# 3    400 /football/players/stats: Invalid player_id
# 4    400 /football/players/stats: Invalid player_id
# ..                                              ...
# 175  400 /football/players/stats: Invalid player_id
# 176  400 /football/players/stats: Invalid player_id
# 177  400 /football/players/stats: Invalid player_id
# 178  400 /football/players/stats: Invalid player_id
# 179  400 /football/players/stats: Invalid player_id
#
# [180 rows x 5 columns]
# Unmatched provider names. Add only confirmed differences to TEAM_ALIASES, then rerun; cached API calls will be reused.
#     league   season  match_date           home_name         away_name
# 0   greece  2020-21  2020-09-11   Aris Thessaloniki    PAS Lamia 1964
# 1   greece  2020-21  2020-09-11                PAOK         AE Larisa
# 2   greece  2020-21  2020-09-13    Atromitos Athens         NPS Volos
# 3   greece  2020-21  2020-09-18       Olympiacos FC     Asteras Aktor
# 4   greece  2020-21  2020-09-20      PAS Lamia 1964         OFI Crete
# ..     ...      ...         ...                 ...               ...
# 95  greece  2020-21  2021-02-07       Olympiacos FC         OFI Crete
# 96  greece  2020-21  2021-02-08         Panetolikos      PAS Giannina
# 97  greece  2020-21  2021-02-13       Asteras Aktor    PAS Lamia 1964
# 98  greece  2020-21  2021-02-13  GS Apollon Smyrnis  Atromitos Athens
# 99  greece  2020-21  2021-02-14           OFI Crete         NPS Volos
#
# [100 rows x 5 columns]

# %%
# Small, reusable audit outputs. This does not save raw player data.
if audit_rows:
    output_dir = Path("artifacts/statsapi_coverage_audit")
    output_dir.mkdir(parents=True, exist_ok=True)
    audit_summary.to_csv(output_dir / "league_season_summary.csv", index=False)
    if detail_rows:
        detail_df.to_csv(output_dir / "sample_match_details.csv", index=False)
        field_summary.to_csv(output_dir / "player_stat_fields.csv", index=False)
    if unmatched_rows:
        pd.DataFrame(unmatched_rows).drop_duplicates().to_csv(output_dir / "unmatched_teams.csv", index=False)
    print("Saved audit tables to", output_dir)
# Out:
# Saved audit tables to artifacts\statsapi_coverage_audit

# %%
api_get("/football/matches/mt_138510863/player-stats")
# Out:
# {'data': [{'player_id': 'pl_45891902',
#    'player_name': 'Alfredo Morelos',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_66443',
#    'position': 'F',
#    'rating': 7.69,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 39,
#     'accurate_passes': 32,
#     'key_passes': 3,
#     'assists': 1,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 2,
#     'accurate_long_balls': 1},
#    'shooting': {'goals': 0,
#     'total_shots': 4,
#     'shots_on_target': 0,
#     'shots_off_target': 3,
#     'blocked_shots': 1,
#     'big_chances_created': 1,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0.04},
#    'duels': {'duel_won': 13,
#     'duel_lost': 12,
#     'aerial_won': 3,
#     'challenge_lost': 0,
#     'won_contest': 3,
#     'dispossessed': 1},
#    'defending': {'tackles': 3, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 68,
#     'fouls': 5,
#     'was_fouled': 4,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 17,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_727956',
#    'player_name': 'Allan McGregor',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'G',
#    'rating': 7.36,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 31,
#     'accurate_passes': 24,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 12,
#     'accurate_long_balls': 5},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 40,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 8,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_0188041',
#    'player_name': 'James Tavernier',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'D',
#    'rating': 7.34,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 49,
#     'accurate_passes': 36,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 2,
#     'accurate_crosses': 0,
#     'total_long_balls': 12,
#     'accurate_long_balls': 4},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 1,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 13,
#     'duel_lost': 5,
#     'aerial_won': 2,
#     'challenge_lost': 2,
#     'won_contest': 1,
#     'dispossessed': 1},
#    'defending': {'tackles': 10, 'interceptions': 3, 'clearances': 2},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 93,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 21,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_2783268',
#    'player_name': 'Borna Barišić',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_19837',
#    'position': 'D',
#    'rating': 7.41,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 38,
#     'accurate_passes': 30,
#     'key_passes': 2,
#     'assists': 0,
#     'total_crosses': 8,
#     'accurate_crosses': 1,
#     'total_long_balls': 4,
#     'accurate_long_balls': 1},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 4,
#     'duel_lost': 3,
#     'aerial_won': 1,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 2, 'interceptions': 0, 'clearances': 2},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 59,
#     'fouls': 1,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 18,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_039798',
#    'player_name': 'Leon Balogun',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_38138',
#    'position': 'D',
#    'rating': 7.93,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 69,
#     'accurate_passes': 61,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 5,
#     'accurate_long_balls': 3},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 9,
#     'duel_lost': 0,
#     'aerial_won': 6,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 1, 'interceptions': 0, 'clearances': 3},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 77,
#     'fouls': 0,
#     'was_fouled': 2,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 8,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_84434643',
#    'player_name': 'Ryan Kent',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'F',
#    'rating': 7.34,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 51,
#     'accurate_passes': 46,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 1,
#     'accurate_crosses': 1,
#     'total_long_balls': 1,
#     'accurate_long_balls': 1},
#    'shooting': {'goals': 1,
#     'total_shots': 2,
#     'shots_on_target': 1,
#     'shots_off_target': 0,
#     'blocked_shots': 1,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0.12},
#    'duels': {'duel_won': 6,
#     'duel_lost': 4,
#     'aerial_won': 0,
#     'challenge_lost': 2,
#     'won_contest': 4,
#     'dispossessed': 0},
#    'defending': {'tackles': 1, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 70,
#     'fouls': 0,
#     'was_fouled': 1,
#     'offsides': 2,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 10,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_57293736',
#    'player_name': 'Joe Aribo',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 7.41,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 34,
#     'accurate_passes': 33,
#     'key_passes': 3,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 1,
#     'accurate_long_balls': 1},
#    'shooting': {'goals': 0,
#     'total_shots': 3,
#     'shots_on_target': 2,
#     'shots_off_target': 0,
#     'blocked_shots': 1,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0.12},
#    'duels': {'duel_won': 10,
#     'duel_lost': 9,
#     'aerial_won': 1,
#     'challenge_lost': 0,
#     'won_contest': 4,
#     'dispossessed': 3},
#    'defending': {'tackles': 3, 'interceptions': 2, 'clearances': 1},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 66,
#     'fouls': 1,
#     'was_fouled': 2,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 12,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_0114152',
#    'player_name': 'Connor Goldson',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_91400',
#    'position': 'D',
#    'rating': 7.67,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 79,
#     'accurate_passes': 64,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 15,
#     'accurate_long_balls': 6},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 12,
#     'duel_lost': 4,
#     'aerial_won': 5,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 3, 'interceptions': 0, 'clearances': 2},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 88,
#     'fouls': 2,
#     'was_fouled': 4,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 15,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_08251431',
#    'player_name': 'Ianis Hagi',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_99419',
#    'position': 'F',
#    'rating': 7.36,
#    'started': True,
#    'played': True,
#    'minutes_played': 77,
#    'passing': {'total_passes': 38,
#     'accurate_passes': 32,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 2,
#     'accurate_crosses': 0,
#     'total_long_balls': 2,
#     'accurate_long_balls': 2},
#    'shooting': {'goals': 0,
#     'total_shots': 4,
#     'shots_on_target': 1,
#     'shots_off_target': 1,
#     'blocked_shots': 2,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 8,
#     'duel_lost': 7,
#     'aerial_won': 2,
#     'challenge_lost': 0,
#     'won_contest': 1,
#     'dispossessed': 0},
#    'defending': {'tackles': 2, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 59,
#     'fouls': 2,
#     'was_fouled': 3,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 15,
#     'player_subbed_on': 'pl_629491',
#     'player_subbed_off': None}},
#   {'player_id': 'pl_317276',
#    'player_name': 'Ryan Jack',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_1004400',
#    'position': 'M',
#    'rating': 6.57,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 91,
#     'accurate_passes': 81,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 8,
#     'accurate_long_balls': 5},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 3,
#     'duel_lost': 4,
#     'aerial_won': 2,
#     'challenge_lost': 0,
#     'won_contest': 1,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 2, 'clearances': 2},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 100,
#     'fouls': 2,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 10,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_4748756',
#    'player_name': 'Glen Kamara',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_2949',
#    'position': 'M',
#    'rating': 6.58,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 72,
#     'accurate_passes': 65,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 1,
#     'accurate_crosses': 0,
#     'total_long_balls': 4,
#     'accurate_long_balls': 2},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 1,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 7,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 3},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 1},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 79,
#     'fouls': 1,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 11,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_8335424',
#    'player_name': 'Matthew Kennedy',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 5.75,
#    'started': True,
#    'played': True,
#    'minutes_played': 70,
#    'passing': {'total_passes': 14,
#     'accurate_passes': 11,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 2,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 2,
#     'duel_lost': 10,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 1,
#     'dispossessed': 7},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 34,
#     'fouls': 0,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 18,
#     'player_subbed_on': 'pl_340345',
#     'player_subbed_off': None}},
#   {'player_id': 'pl_760744',
#    'player_name': 'Ash Taylor',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_8343334',
#    'position': 'D',
#    'rating': 7.83,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 27,
#     'accurate_passes': 22,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 6,
#     'accurate_long_balls': 2},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 1,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 6,
#     'duel_lost': 1,
#     'aerial_won': 4,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 2, 'interceptions': 3, 'clearances': 4},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 43,
#     'fouls': 1,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 5,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_96487884',
#    'player_name': 'Lewis Ferguson',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_46156',
#    'position': 'M',
#    'rating': 5.95,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 46,
#     'accurate_passes': 39,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 8,
#     'accurate_long_balls': 7},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 1,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 5,
#     'duel_lost': 13,
#     'aerial_won': 1,
#     'challenge_lost': 6,
#     'won_contest': 0,
#     'dispossessed': 1},
#    'defending': {'tackles': 2, 'interceptions': 2, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 58,
#     'fouls': 4,
#     'was_fouled': 2,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 9,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_61191',
#    'player_name': 'Joe Lewis',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'G',
#    'rating': 6.84,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 41,
#     'accurate_passes': 31,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 27,
#     'accurate_long_balls': 17},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 1},
#    'goalkeeping': {'saves': 2},
#    'general': {'touches': 47,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 10,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_933302',
#    'player_name': 'Funso Ojo',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 6.32,
#    'started': True,
#    'played': True,
#    'minutes_played': 78,
#    'passing': {'total_passes': 33,
#     'accurate_passes': 26,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 4,
#     'accurate_long_balls': 3},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 1,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 2,
#     'duel_lost': 8,
#     'aerial_won': 0,
#     'challenge_lost': 2,
#     'won_contest': 0,
#     'dispossessed': 3},
#    'defending': {'tackles': 1, 'interceptions': 1, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 47,
#     'fouls': 2,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 1,
#     'red_cards': 0,
#     'possession_lost': 12,
#     'player_subbed_on': 'pl_13330146',
#     'player_subbed_off': None}},
#   {'player_id': 'pl_57458983',
#    'player_name': 'Ronald Hernández',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_2693776',
#    'position': 'D',
#    'rating': 5.95,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 42,
#     'accurate_passes': 25,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 3,
#     'accurate_crosses': 0,
#     'total_long_balls': 10,
#     'accurate_long_balls': 1},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 5,
#     'duel_lost': 4,
#     'aerial_won': 3,
#     'challenge_lost': 1,
#     'won_contest': 0,
#     'dispossessed': 1},
#    'defending': {'tackles': 0, 'interceptions': 1, 'clearances': 3},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 56,
#     'fouls': 2,
#     'was_fouled': 2,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 22,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_8620327',
#    'player_name': 'Scott McKenna',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_97303',
#    'position': 'D',
#    'rating': 7.36,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 55,
#     'accurate_passes': 42,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 11,
#     'accurate_long_balls': 4},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 5,
#     'duel_lost': 5,
#     'aerial_won': 2,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 2, 'interceptions': 1, 'clearances': 2},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 65,
#     'fouls': 2,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 14,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_135616',
#    'player_name': 'Andy Considine',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'D',
#    'rating': 6.29,
#    'started': True,
#    'played': True,
#    'minutes_played': 86,
#    'passing': {'total_passes': 55,
#     'accurate_passes': 41,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 6,
#     'accurate_long_balls': 4},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 6,
#     'duel_lost': 7,
#     'aerial_won': 3,
#     'challenge_lost': 1,
#     'won_contest': 0,
#     'dispossessed': 3},
#    'defending': {'tackles': 3, 'interceptions': 4, 'clearances': 1},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 93,
#     'fouls': 2,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 1,
#     'possession_lost': 20,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_962884',
#    'player_name': 'Jonny Hayes',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 6.84,
#    'started': True,
#    'played': True,
#    'minutes_played': 90,
#    'passing': {'total_passes': 22,
#     'accurate_passes': 14,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 4,
#     'accurate_crosses': 1,
#     'total_long_balls': 6,
#     'accurate_long_balls': 3},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 6,
#     'duel_lost': 7,
#     'aerial_won': 2,
#     'challenge_lost': 0,
#     'won_contest': 2,
#     'dispossessed': 2},
#    'defending': {'tackles': 1, 'interceptions': 1, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 45,
#     'fouls': 2,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 21,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_380454',
#    'player_name': 'Craig Bryson',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_15995',
#    'position': 'F',
#    'rating': 7.36,
#    'started': True,
#    'played': True,
#    'minutes_played': 70,
#    'passing': {'total_passes': 17,
#     'accurate_passes': 11,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 10,
#     'duel_lost': 4,
#     'aerial_won': 3,
#     'challenge_lost': 1,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 4, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 29,
#     'fouls': 1,
#     'was_fouled': 3,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 9,
#     'player_subbed_on': 'pl_96297033',
#     'player_subbed_off': None}},
#   {'player_id': 'pl_30164288',
#    'player_name': 'Bruce Anderson',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'F',
#    'rating': 5.95,
#    'started': True,
#    'played': True,
#    'minutes_played': 65,
#    'passing': {'total_passes': 6,
#     'accurate_passes': 3,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 10,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 1},
#    'defending': {'tackles': 0, 'interceptions': 1, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 10,
#     'fouls': 1,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 5,
#     'player_subbed_on': 'pl_30273444',
#     'player_subbed_off': None}},
#   {'player_id': 'pl_629491',
#    'player_name': 'Scott Arfield',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 6.71,
#    'started': False,
#    'played': True,
#    'minutes_played': 13,
#    'passing': {'total_passes': 6,
#     'accurate_passes': 5,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 1,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 3,
#     'duel_lost': 1,
#     'aerial_won': 1,
#     'challenge_lost': 1,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 1, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 10,
#     'fouls': 0,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 1,
#     'player_subbed_on': None,
#     'player_subbed_off': 'pl_08251431'}},
#   {'player_id': 'pl_340345',
#    'player_name': 'Niall McGinn',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_76179',
#    'position': 'M',
#    'rating': 7.1,
#    'started': False,
#    'played': True,
#    'minutes_played': 20,
#    'passing': {'total_passes': 12,
#     'accurate_passes': 10,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 1,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 1,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 1,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0.01},
#    'duels': {'duel_won': 3,
#     'duel_lost': 1,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 1,
#     'dispossessed': 0},
#    'defending': {'tackles': 1, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 20,
#     'fouls': 0,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 5,
#     'player_subbed_on': None,
#     'player_subbed_off': 'pl_8335424'}},
#   {'player_id': 'pl_96297033',
#    'player_name': 'Dean Campbell',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_3279',
#    'position': 'M',
#    'rating': 6.29,
#    'started': False,
#    'played': True,
#    'minutes_played': 20,
#    'passing': {'total_passes': 12,
#     'accurate_passes': 9,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 1,
#     'accurate_crosses': 0,
#     'total_long_balls': 3,
#     'accurate_long_balls': 2},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 4,
#     'duel_lost': 4,
#     'aerial_won': 0,
#     'challenge_lost': 3,
#     'won_contest': 1,
#     'dispossessed': 1},
#    'defending': {'tackles': 2, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 19,
#     'fouls': 0,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 5,
#     'player_subbed_on': None,
#     'player_subbed_off': 'pl_380454'}},
#   {'player_id': 'pl_13330146',
#    'player_name': 'Ryan Hedges',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 6.09,
#    'started': False,
#    'played': True,
#    'minutes_played': 12,
#    'passing': {'total_passes': 4,
#     'accurate_passes': 4,
#     'key_passes': 1,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 3,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 6,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 1,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 1,
#     'player_subbed_on': None,
#     'player_subbed_off': 'pl_933302'}},
#   {'player_id': 'pl_30273444',
#    'player_name': 'Ryan Edmondson',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_79322',
#    'position': 'F',
#    'rating': 6.29,
#    'started': False,
#    'played': True,
#    'minutes_played': 25,
#    'passing': {'total_passes': 10,
#     'accurate_passes': 8,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 2,
#     'duel_lost': 4,
#     'aerial_won': 2,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 1},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 13,
#     'fouls': 1,
#     'was_fouled': 1,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 4,
#     'player_subbed_on': None,
#     'player_subbed_off': 'pl_30164288'}},
#   {'player_id': 'pl_286736',
#    'player_name': 'Jon McLaughlin',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_6387',
#    'position': 'G',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_7460947',
#    'player_name': 'Filip Helander',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_19576',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_96228824',
#    'player_name': 'Calvin Bassey',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_5290',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_29256003',
#    'player_name': 'Nathan Patterson',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_544782',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_84505980',
#    'player_name': 'George Edmundson',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_6387',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_8328525',
#    'player_name': 'Greg Stewart',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'M',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_58666292',
#    'player_name': 'Jamie Murphy',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_02189',
#    'position': 'M',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_8086725',
#    'player_name': 'Brandon Barker',
#    'team_id': 'tm_20535',
#    'club_team_id': 'tm_9103469',
#    'position': 'F',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_847087',
#    'player_name': 'Tomas Cerny',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'G',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_9773021',
#    'player_name': 'Tommie Hoban',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_9103469',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_914303',
#    'player_name': 'Shaleum Logan',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_19908617',
#    'position': 'D',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_0835879',
#    'player_name': 'Dylan McGeouch',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_1914458',
#    'position': 'M',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}},
#   {'player_id': 'pl_84046049',
#    'player_name': 'Connor McLennan',
#    'team_id': 'tm_46091',
#    'club_team_id': 'tm_64280',
#    'position': 'F',
#    'rating': 0,
#    'started': False,
#    'played': False,
#    'minutes_played': 0,
#    'passing': {'total_passes': 0,
#     'accurate_passes': 0,
#     'key_passes': 0,
#     'assists': 0,
#     'total_crosses': 0,
#     'accurate_crosses': 0,
#     'total_long_balls': 0,
#     'accurate_long_balls': 0},
#    'shooting': {'goals': 0,
#     'total_shots': 0,
#     'shots_on_target': 0,
#     'shots_off_target': 0,
#     'blocked_shots': 0,
#     'big_chances_created': 0,
#     'expected_goals': 0,
#     'expected_assists': 0,
#     'np_expected_goals': 0},
#    'duels': {'duel_won': 0,
#     'duel_lost': 0,
#     'aerial_won': 0,
#     'challenge_lost': 0,
#     'won_contest': 0,
#     'dispossessed': 0},
#    'defending': {'tackles': 0, 'interceptions': 0, 'clearances': 0},
#    'goalkeeping': {'saves': 0},
#    'general': {'touches': 0,
#     'fouls': 0,
#     'was_fouled': 0,
#     'offsides': 0,
#     'yellow_cards': 0,
#     'red_cards': 0,
#     'possession_lost': 0,
#     'player_subbed_on': None,
#     'player_subbed_off': None}}]}
